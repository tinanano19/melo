# %% [markdown]
# <a href="https://colab.research.google.com/github/tinanano19/melo/blob/master/caramelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***`ESTO ES BRUJERIA`***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# importar librerias

import numpy as np
import matplotlib.pyplot as plt
import cv2

# grafica imagenes estaticas en el notebook
# %matplotlib inline

# %%
#Como cambiar el tamaño codigo de terminal

# !pwd
# %ls
# %cd /content/drive/My Drive/melo/
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('ricardo.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img, (int(200),int(100)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/melo
# ricardo.jpg
# /content/drive/My Drive/melo
# /content/drive/My Drive/melo
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F8B381F8E10>

# %%
#Como cambiar el tamaño Phyton

import os

path='/content/drive/My Drive/melo/'
os.chdir(path)
#chdir es igual a cd, pero en phyton
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('ricardo.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img, (int(200),int(100)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/melo
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F8B381F88D0>

# %%
# error 

image = cv2.imread('/content/drive/My Drive/melo/ricardo-milos.jpg')
cv2.imshow("image", image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-3-4941a4a473ce> in <module>()
#       1 image = cv2.imread('/content/drive/My Drive/melo/ricardo-milos.jpg')
# ----> 2 cv2.imshow("image", image)
#       3 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
# solucion

from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/melo/ricardo.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F55ACFCC630>

# %%
#CARGAR Y VISUALIZAR IMAGEN CON MATPLOTLIB

# Leer una imagen

img_BGR = cv2.imread('/content/drive/My Drive/melo/ricardo.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(3,3))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# # **Cambiar tamaños de la imagen**

# %%
#Expandir

print(img.shape)
res = cv2.resize(img, None,fx=10, fy=10, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (100, 200, 3)
# (1000, 2000, 3)

# %%
#Contraer

print(img.shape)
res = cv2.resize(img, None,fx=.3, fy=.3, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (100, 200, 3)
# (30, 60, 3)

# %% [markdown]
# # **Remover numeracion de los ejes**

# %%
plt.figure(figsize=(3,3))
plt.imshow(img_BGR)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Cambiar de BGR a RGB**

# %%
#Pasar la imagen a RGB

img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(3,3))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Convertir a escalas de grises**

# %%
#Pasar la imagen a Gris (Asi no cambia a gris xd)

img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(3,3))
plt.imshow(img_GRAY)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Pasar la imagen a Gris (Asi si cambia a gris xd)

img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(3,3))
plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Usar metodos para mostrar las imagenes (Phyton)**

# %%
#Pantalla dos imagenes
def display(a, b, title1='Original', title2='Editada'):
    plt.figure(figsize=(14,14))
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
#Pantalla dos imagenes
def display_one(a, title1 = "Original"):
    plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
display_one(img_BGR) #Corre el metodo que se elija

# %%
display(img_BGR,img_RGB,"BGR","RGB")

# %%
#Pantalla dos imagenes
def display4(a, b, c, d, title1='Original', title2='Editada1', title3='Editada2', title4='Editada3'):
    plt.figure(figsize=(14,14))
    plt.subplot(221), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(222), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(223), plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(224), plt.imshow(d, cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
    display4(img_BGR,img_RGB, img_GRAY, img_GRAY, "BGR","RGB", "GRAY", "GRAY")
